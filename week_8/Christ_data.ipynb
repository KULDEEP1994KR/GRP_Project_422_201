# %%
import pandas as pd

# %%
all_christ= pd.read_csv(r"C:\Users\VISHAL\Desktop\g2\All_chrch_file.csv")

# %%
all_christ.sample(10)
# Out:
#                         id                                            name  \
# 6691   1151169759957143703  Delightful CBD 2 Bed 2 Baths - Stylish Getaway
# 11477  1564152361494890963                Cozy single bedroom near airport
# 20420  1168545987995635331                  Haka House - King Room Ensuite
# 23902   809778469981150692                   City lights, Mountain heights
# 18526  1608572829787605856    City Stay, Sleeps 6 - Walk to One NZ Stadium
# 27258  1062391302156960250          Your own space in our hillside cottage
# 10769             45899184                                      Park Motel
# 13950   665517904619564738       Woodills Wonderland – Akaroa Holiday Home
# 17395  1262502977104510298                Fun relaxing home away from home
# 3487    783422501515727269            NEW Studio 1 Bed/ 1 bath/ kit/living
#
#            host_id                       host_name neighbourhood_group  \
# 6691    49642171.0                          Xihang   Christchurch City
# 11477  108930058.0                           Yulin   Christchurch City
# 20420  565751605.0  Haka House Hostel Christchurch   Christchurch City
# 23902  497329414.0                         Michael   Christchurch City
# 18526  551181197.0             Paula Kat Charlotte   Christchurch City
# 27258   14035453.0                            Mark   Christchurch City
# 10769   98758734.0        North South Holiday Park   Christchurch City
# 13950  145244100.0                        Bachcare   Christchurch City
# 17395  484074723.0                           Emily   Christchurch City
# 3487   103297640.0                           Alana   Christchurch City
#
#               neighbourhood   latitude   longitude        room_type  price  \
# 6691           Central Ward -43.532590  172.650210  Entire home/apt    NaN
# 11477           Hornby Ward -43.531750  172.528030     Private room    NaN
# 20420          Central Ward -43.532216  172.629874     Private room  162.0
# 23902        Heathcote Ward -43.562280  172.712870  Entire home/apt    NaN
# 18526          Central Ward -43.531577  172.647996  Entire home/apt  288.0
# 27258         Cashmere Ward -43.579115  172.630513     Private room  121.0
# 10769         Harewood Ward -43.469820  172.571010     Private room    NaN
# 13950  Banks Peninsula Ward -43.801230  172.970790  Entire home/apt    NaN
# 17395        Heathcote Ward -43.563921  172.669146  Entire home/apt  401.0
# 3487         Heathcote Ward -43.549285  172.628307  Entire home/apt  108.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 6691              1.0                 11  2025-11-30               0.61
# 11477             1.0                  0         NaN                NaN
# 20420             1.0                  3  2025-11-22               0.17
# 23902             2.0                  0         NaN                NaN
# 18526             1.0                  2  2026-02-21               1.20
# 27258             2.0                 34  2026-04-18               1.26
# 10769             1.0                  2  2022-07-15               0.03
# 13950             2.0                 13  2025-11-15               0.39
# 17395             6.0                  2  2025-04-22               0.14
# 3487              2.0                 79  2025-09-21               2.34
#
#        calculated_host_listings_count  availability_365  \
# 6691                             88.0               287
# 11477                             1.0               364
# 20420                            10.0               317
# 23902                             1.0               364
# 18526                           188.0               262
# 27258                             1.0               259
# 10769                            19.0               337
# 13950                          1470.0               365
# 17395                             1.0                86
# 3487                              1.0                78
#
#        number_of_reviews_ltm  license    Pub_date  Difference_date
# 6691                       6      NaN  2025-12-11             11.0
# 11477                      0      NaN  2026-01-16              NaN
# 20420                      1      NaN  2026-04-16            145.0
# 23902                      0      NaN  2026-05-23              NaN
# 18526                      2      NaN  2026-03-17             24.0
# 27258                      5      NaN  2026-06-19             62.0
# 10769                      0      NaN  2026-01-16           1281.0
# 13950                      2      NaN  2026-02-13             90.0
# 17395                      1      NaN  2026-03-17            329.0
# 3487                      32      NaN  2025-11-07             47.0

# %%
df_all_christ= all_christ.drop(columns=["license","id",])

# %%
df_all_christ.sample(10)
# Out:
#                                                     name      host_id  \
# 25403  Bottle Lake En-suite. Warm/Private/ 12pm check...   88769311.0
# 5924                                  House of Serenity.  547933078.0
# 1652                       Central City Loft - Sleeps 10  202585247.0
# 4435                          warm house in south island  231538523.0
# 3013                              Self Contained Unit 18   98758734.0
# 27477        Guest Favourite l Spacious 4BR Near Airport   49642171.0
# 18201  Cosy Loft 3.5 km city 8.5 km Airport free parking  725873253.0
# 24667       Plush Upmarket Close Hospital  2Bdrm 2 Bthrm   45768555.0
# 21251  Modern Bright 2BR w/ Balcony & Hagley Park Out...  482671075.0
# 10704                            Peaceful garden cottage     201748.0
#
#                       host_name neighbourhood_group  neighbourhood   latitude  \
# 25403                     Steve   Christchurch City   Coastal Ward -43.471050
# 5924                   Birendra   Christchurch City   Linwood Ward -43.550120
# 1652                      Ohana   Christchurch City   Central Ward -43.533150
# 4435                        Mia   Christchurch City   Burwood Ward -43.504500
# 3013   North South Holiday Park   Christchurch City  Harewood Ward -43.470920
# 27477           Lily-SimplyHost   Christchurch City    Hornby Ward -43.519228
# 18201                     Tania   Christchurch City     Innes Ward -43.498340
# 24667  Hasslefree Accommodation   Christchurch City   Central Ward -43.519315
# 21251       Care Property Stays   Christchurch City   Central Ward -43.538345
# 10704                     Debby   Christchurch City  Cashmere Ward -43.563657
#
#         longitude        room_type  price  minimum_nights  number_of_reviews  \
# 25403  172.699430  Entire home/apt   99.0             1.0                564
# 5924   172.689800     Private room   55.0             1.0                 12
# 1652   172.638110  Entire home/apt  304.0             1.0                312
# 4435   172.694220  Entire home/apt  216.0             1.0                202
# 3013   172.569660     Private room  235.0             1.0                  1
# 27477  172.525894  Entire home/apt  350.0             1.0                 35
# 18201  172.640290  Entire home/apt   97.0             1.0                 61
# 24667  172.630619  Entire home/apt  270.0             1.0                  4
# 21251  172.621003  Entire home/apt  206.0             1.0                 29
# 10704  172.640389  Entire home/apt    NaN             2.0                 95
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 25403  2026-06-13               6.37                             1.0
# 5924   2025-02-25               0.53                             2.0
# 1652   2025-07-27               7.90                           121.0
# 4435   2025-09-19               2.42                             1.0
# 3013   2020-12-30               0.02                            19.0
# 27477  2026-05-18               2.88                            95.0
# 18201  2026-03-21              13.56                             1.0
# 24667  2026-05-08               2.50                            64.0
# 21251  2026-04-06               3.82                           154.0
# 10704  2026-01-17               2.63                             1.0
#
#        availability_365  number_of_reviews_ltm    Pub_date  Difference_date
# 25403               117                     81  2026-06-19              6.0
# 5924                264                      2  2025-11-07            255.0
# 1652                  0                     61  2025-11-07            103.0
# 4435                139                     22  2025-11-07             49.0
# 3013                324                      0  2025-11-07           1773.0
# 27477               298                     35  2026-06-19             32.0
# 18201                14                     61  2026-03-17             -4.0
# 24667                69                      4  2026-05-23             15.0
# 21251               240                     29  2026-04-16             10.0
# 10704               307                     17  2026-01-16             -1.0

# %%
df_all_christ.dtypes
# Out:
# name                                  str
# host_id                           float64
# host_name                             str
# neighbourhood_group                   str
# neighbourhood                         str
# latitude                          float64
# longitude                         float64
# room_type                             str
# price                             float64
# minimum_nights                    float64
# number_of_reviews                   int64
# last_review                           str
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                    int64
# number_of_reviews_ltm               int64
# Pub_date                              str
# Difference_date                   float64
# dtype: object

# %%
df_all_christ['last_review']=pd.to_datetime(df_all_christ['last_review'])
df_all_christ['Pub_date']=pd.to_datetime(df_all_christ['Pub_date'])
df_all_christ['reviews_per_month']=pd.to_datetime(df_all_christ['reviews_per_month'])

# %%
df_all_christ.dtypes
# Out:
# name                                         str
# host_id                                  float64
# host_name                                    str
# neighbourhood_group                          str
# neighbourhood                                str
# latitude                                 float64
# longitude                                float64
# room_type                                    str
# price                                    float64
# minimum_nights                           float64
# number_of_reviews                          int64
# last_review                       datetime64[us]
# reviews_per_month                 datetime64[ns]
# calculated_host_listings_count           float64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# Pub_date                          datetime64[us]
# Difference_date                          float64
# dtype: object

# %%
df_all_christ["price"].isnull().sum()
# Out:
# np.int64(10667)

# %%
df_all_christ.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28795 entries, 0 to 28794
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            28795 non-null  str
#  1   host_id                         28795 non-null  float64
#  2   host_name                       28794 non-null  str
#  3   neighbourhood_group             28795 non-null  str
#  4   neighbourhood                   28795 non-null  str
#  5   latitude                        28795 non-null  float64
#  6   longitude                       28795 non-null  float64
#  7   room_type                       28795 non-null  str
#  8   price                           18128 non-null  float64
#  9   minimum_nights                  28758 non-null  float64
#  10  number_of_reviews               28795 non-null  int64
#  11  last_review                     26168 non-null  datetime64[us]
#  12  reviews_per_month               26168 non-null  datetime64[ns]
#  13  calculated_host_listings_count  28795 non-null  float64
#  14  availability_365                28795 non-null  int64
#  15  number_of_reviews_ltm           28795 non-null  int64
#  16  Pub_date                        28795 non-null  datetime64[us]
#  17  Difference_date                 26168 non-null  float64
# dtypes: datetime64[ns](1), datetime64[us](2), float64(7), int64(3), str(5)
# memory usage: 4.0 MB

# %%
df_all_christ["last_review"].isnull().sum()
# Out:
# np.int64(2627)

# %%
print(df_all_christ.loc[df_all_christ['price'].isna(), 'price'])
# Out:
# 0       NaN
# 1       NaN
# 3       NaN
# 8       NaN
# 9       NaN
#          ..
# 28764   NaN
# 28765   NaN
# 28766   NaN
# 28767   NaN
# 28794   NaN
# Name: price, Length: 10667, dtype: float64

# %%
df_all_christ.duplicated().sum()
# Out:
# np.int64(112)

# %%
df_all_christ[df_all_christ.duplicated(keep=False)]
# Out:
#                                        name      host_id      host_name  \
# 3                   Settle into the sun set   54299306.0         Sarena
# 10    Room 3queen bedroom/separate bathroom   27743702.0          David
# 23         Max Penthouse 3 Bedroom with Spa  179297759.0           Peng
# 43                                   Cabino     962345.0          Rollo
# 45                          Beachside cabin  498286875.0           Anna
# ...                                     ...          ...            ...
# 5921                        Woolston wonder   91437295.0         Prisca
# 5937                       Birdsong retreat  216305400.0  Christine Joy
# 5942      Room with a View to the Mountains   32636421.0          Karyn
# 5944                       Room with a View   32636421.0          Karyn
# 5994         Entire 2-bed House in Woolston  159021723.0           Mark
#
#      neighbourhood_group         neighbourhood   latitude   longitude  \
# 3      Christchurch City          Burwood Ward -43.482864  172.668660
# 10     Christchurch City          Central Ward -43.518340  172.649520
# 23     Christchurch City        Riccarton Ward -43.538441  172.578975
# 43     Christchurch City  Banks Peninsula Ward -43.785650  172.808740
# 45     Christchurch City          Coastal Ward -43.527826  172.736001
# ...                  ...                   ...        ...         ...
# 5921   Christchurch City          Linwood Ward -43.552232  172.686745
# 5937   Christchurch City         Cashmere Ward -43.564360  172.630440
# 5942   Christchurch City         Cashmere Ward -43.568140  172.647830
# 5944   Christchurch City         Cashmere Ward -43.566430  172.648140
# 5994   Christchurch City          Linwood Ward -43.554270  172.671880
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 3     Entire home/apt    NaN             2.0                  2  2025-04-26
# 10       Private room    NaN             7.0                  1  2025-03-18
# 23    Entire home/apt  290.0             1.0                  2  2025-01-30
# 43    Entire home/apt  233.0             1.0                  1  2023-03-19
# 45    Entire home/apt  108.0             1.0                  3  2025-02-23
# ...               ...    ...             ...                ...         ...
# 5921  Entire home/apt  147.0             2.0                  0         NaT
# 5937     Private room   88.0             2.0                 13  2025-02-21
# 5942     Private room  130.0             2.0                 13  2025-02-10
# 5944     Private room   99.0             1.0                  2  2025-02-22
# 5994  Entire home/apt    NaN            10.0                  5  2025-02-22
#
#      reviews_per_month  calculated_host_listings_count  availability_365  \
# 3           1970-01-01                             1.0                 0
# 10          1970-01-01                             4.0                 0
# 23          1970-01-01                            20.0               264
# 43          1970-01-01                             1.0                89
# 45          1970-01-01                             2.0               269
# ...                ...                             ...               ...
# 5921               NaT                             1.0                88
# 5937        1970-01-01                             1.0                88
# 5942        1970-01-01                             2.0               364
# 5944        1970-01-01                             2.0               362
# 5994        1970-01-01                             1.0                 0
#
#       number_of_reviews_ltm   Pub_date  Difference_date
# 3                         2 2025-11-07            195.0
# 10                        1 2025-11-07            234.0
# 23                        2 2025-11-07            281.0
# 43                        0 2025-11-07            964.0
# 45                        2 2025-11-07            257.0
# ...                     ...        ...              ...
# 5921                      0 2025-11-07              NaN
# 5937                      1 2025-11-07            259.0
# 5942                      1 2025-11-07            270.0
# 5944                      2 2025-11-07            258.0
# 5994                      2 2025-11-07            258.0
#
# [224 rows x 18 columns]

# %%
df_all_christ[['name', 'host_id', 'host_name']].nunique()
# Out:
# name         4854
# host_id      2103
# host_name    1422
# dtype: int64

# %%
df_all_christ.groupby(
    ['name', 'host_id', 'host_name']
).size().sort_values(ascending=False).head(20)
# Out:
# name                                                host_id      host_name
# Waterfront 2-Bedroom Harbour View Apartment         20665858.0   Adam                                  20
# cozycozy guest house                                22181030.0   Flora                                 18
# Deluxe King Room                                    449624343.0  Lucy                                  17
# Quite and Cozy Double Bedroom                       662706872.0  Pratik                                16
# Room in Christchurch                                131216378.0  Adam                                  13
# Spacious stylish home - 7 Night special deals       24205506.0   Mayie, Judi And Karen At Bookahome    12
# Modern King Studio | Netflix, Disney+ & Parking     573757538.0  Prince                                12
# Brand-New 1BR Apartment Near Upcoming Te Kaha       331763232.0  Managed By Williams                   12
# Compact Studio with free Parking                    573757538.0  Prince                                12
# Christchurch Base                                   15484405.0   Clare                                  9
# Christchurch CBD townhouse                          211195948.0  Jenny                                  9
# #72 3 Bedroom Apt with partial Water Views          70726871.0   Darren                                 9
# #1 The Wharf Seaview Apartments by AVI              70726871.0   Darren                                 9
# 都市庄园--杜鹃园                                           46874226.0   Jielian                                9
# super king size bed give you comfortable enjoyment  114475989.0  Vince                                  9
# #2 The Wharf Seaview Apartments by AVI              70726871.0   Darren                                 9
# #25 The Bruce Waterfront Apartments by AVI          70726871.0   Darren                                 9
# #3 - The Wharf Seaview Apartments by AVI            70726871.0   Darren                                 9
# #4 The Wharf Seaview  Apartments by AVI             70726871.0   Darren                                 9
# ‘Home away from Home’ - Yaldhurst                   161527985.0  Colleen                                9
# dtype: int64

# %%
exact_duplicates = df_all_christ[
    df_all_christ.duplicated(keep=False)
]

exact_duplicates
# Out:
#                                        name      host_id      host_name  \
# 3                   Settle into the sun set   54299306.0         Sarena
# 10    Room 3queen bedroom/separate bathroom   27743702.0          David
# 23         Max Penthouse 3 Bedroom with Spa  179297759.0           Peng
# 43                                   Cabino     962345.0          Rollo
# 45                          Beachside cabin  498286875.0           Anna
# ...                                     ...          ...            ...
# 5921                        Woolston wonder   91437295.0         Prisca
# 5937                       Birdsong retreat  216305400.0  Christine Joy
# 5942      Room with a View to the Mountains   32636421.0          Karyn
# 5944                       Room with a View   32636421.0          Karyn
# 5994         Entire 2-bed House in Woolston  159021723.0           Mark
#
#      neighbourhood_group         neighbourhood   latitude   longitude  \
# 3      Christchurch City          Burwood Ward -43.482864  172.668660
# 10     Christchurch City          Central Ward -43.518340  172.649520
# 23     Christchurch City        Riccarton Ward -43.538441  172.578975
# 43     Christchurch City  Banks Peninsula Ward -43.785650  172.808740
# 45     Christchurch City          Coastal Ward -43.527826  172.736001
# ...                  ...                   ...        ...         ...
# 5921   Christchurch City          Linwood Ward -43.552232  172.686745
# 5937   Christchurch City         Cashmere Ward -43.564360  172.630440
# 5942   Christchurch City         Cashmere Ward -43.568140  172.647830
# 5944   Christchurch City         Cashmere Ward -43.566430  172.648140
# 5994   Christchurch City          Linwood Ward -43.554270  172.671880
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 3     Entire home/apt    NaN             2.0                  2  2025-04-26
# 10       Private room    NaN             7.0                  1  2025-03-18
# 23    Entire home/apt  290.0             1.0                  2  2025-01-30
# 43    Entire home/apt  233.0             1.0                  1  2023-03-19
# 45    Entire home/apt  108.0             1.0                  3  2025-02-23
# ...               ...    ...             ...                ...         ...
# 5921  Entire home/apt  147.0             2.0                  0         NaT
# 5937     Private room   88.0             2.0                 13  2025-02-21
# 5942     Private room  130.0             2.0                 13  2025-02-10
# 5944     Private room   99.0             1.0                  2  2025-02-22
# 5994  Entire home/apt    NaN            10.0                  5  2025-02-22
#
#      reviews_per_month  calculated_host_listings_count  availability_365  \
# 3           1970-01-01                             1.0                 0
# 10          1970-01-01                             4.0                 0
# 23          1970-01-01                            20.0               264
# 43          1970-01-01                             1.0                89
# 45          1970-01-01                             2.0               269
# ...                ...                             ...               ...
# 5921               NaT                             1.0                88
# 5937        1970-01-01                             1.0                88
# 5942        1970-01-01                             2.0               364
# 5944        1970-01-01                             2.0               362
# 5994        1970-01-01                             1.0                 0
#
#       number_of_reviews_ltm   Pub_date  Difference_date
# 3                         2 2025-11-07            195.0
# 10                        1 2025-11-07            234.0
# 23                        2 2025-11-07            281.0
# 43                        0 2025-11-07            964.0
# 45                        2 2025-11-07            257.0
# ...                     ...        ...              ...
# 5921                      0 2025-11-07              NaN
# 5937                      1 2025-11-07            259.0
# 5942                      1 2025-11-07            270.0
# 5944                      2 2025-11-07            258.0
# 5994                      2 2025-11-07            258.0
#
# [224 rows x 18 columns]

# %%
duplicates = df_all_christ[
    df_all_christ.duplicated(keep=False)
].sort_values(by=df_all_christ.columns.tolist())

duplicates
# Out:
#                                                 name      host_id  \
# 75                                     #Just4Goleman  443017458.0
# 3196                                   #Just4Goleman  443017458.0
# 1264  2 bed house near Beach + Cycleway 15min to CBD   64000316.0
# 3586  2 bed house near Beach + Cycleway 15min to CBD   64000316.0
# 314                     2 bedroom apartment- G02/36B   89191145.0
# ...                                              ...          ...
# 5921                                 Woolston wonder   91437295.0
# 1432         Your Home away from Home - Entire Home.  367682100.0
# 4496         Your Home away from Home - Entire Home.  367682100.0
# 2795                  Your separate space in Wigram.   55360169.0
# 4707                  Your separate space in Wigram.   55360169.0
#
#                    host_name neighbourhood_group   neighbourhood   latitude  \
# 75                       Jay   Christchurch City      Innes Ward -43.498730
# 3196                     Jay   Christchurch City      Innes Ward -43.498730
# 1264                     Sue   Christchurch City  Heathcote Ward -43.559850
# 3586                     Sue   Christchurch City  Heathcote Ward -43.559850
# 314                  Jackson   Christchurch City    Central Ward -43.537061
# ...                      ...                 ...             ...        ...
# 5921                  Prisca   Christchurch City    Linwood Ward -43.552232
# 1432            John Charles   Christchurch City   Halswell Ward -43.577120
# 4496            John Charles   Christchurch City   Halswell Ward -43.577120
# 2795  Tejaskumar Jayeshkumar   Christchurch City   Halswell Ward -43.562142
# 4707  Tejaskumar Jayeshkumar   Christchurch City   Halswell Ward -43.562142
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 75    172.639750     Private room    NaN            16.0                  0
# 3196  172.639750     Private room    NaN            16.0                  0
# 1264  172.738230     Private room  560.0             4.0                 53
# 3586  172.738230     Private room  560.0             4.0                 53
# 314   172.638427  Entire home/apt    NaN             2.0                  4
# ...          ...              ...    ...             ...                ...
# 5921  172.686745  Entire home/apt  147.0             2.0                  0
# 1432  172.565050  Entire home/apt  135.0             3.0                 33
# 4496  172.565050  Entire home/apt  135.0             3.0                 33
# 2795  172.545261  Entire home/apt    NaN             1.0                 22
# 4707  172.545261  Entire home/apt    NaN             1.0                 22
#
#      last_review             reviews_per_month  \
# 75           NaT                           NaT
# 3196         NaT                           NaT
# 1264  2025-09-10 1970-01-01 00:00:00.000000000
# 3586  2025-09-10 1970-01-01 00:00:00.000000000
# 314   2025-01-01 1970-01-01 00:00:00.000000000
# ...          ...                           ...
# 5921         NaT                           NaT
# 1432  2025-10-04 1970-01-01 00:00:00.000000000
# 4496  2025-10-04 1970-01-01 00:00:00.000000000
# 2795  2025-07-26 1970-01-01 00:00:00.000000002
# 4707  2025-07-26 1970-01-01 00:00:00.000000002
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 75                               1.0               269                      0
# 3196                             1.0               269                      0
# 1264                             1.0               270                      3
# 3586                             1.0               270                      3
# 314                              4.0                 0                      1
# ...                              ...               ...                    ...
# 5921                             1.0                88                      0
# 1432                             1.0                 8                      4
# 4496                             1.0                 8                      4
# 2795                             1.0                 0                     22
# 4707                             1.0                 0                     22
#
#        Pub_date  Difference_date
# 75   2025-11-07              NaN
# 3196 2025-11-07              NaN
# 1264 2025-11-07             58.0
# 3586 2025-11-07             58.0
# 314  2025-11-07            310.0
# ...         ...              ...
# 5921 2025-11-07              NaN
# 1432 2025-11-07             34.0
# 4496 2025-11-07             34.0
# 2795 2025-11-07            104.0
# 4707 2025-11-07            104.0
#
# [224 rows x 18 columns]

# %%
df_all_christ = df_all_christ.drop_duplicates()

# %%
df_all_christ.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_all_christ.isna().sum()
# Out:
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             10627
# minimum_nights                       37
# number_of_reviews                     0
# last_review                        2586
# reviews_per_month                  2586
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# Pub_date                              0
# Difference_date                    2586
# dtype: int64

# %%
df_all_christ[df_all_christ['last_review'].isna()]
# Out:
#                                                    name       host_id  \
# 0                              Ensuite Cabin (Sleeps 6)  9.875873e+07
# 5               Merivale Executive Stays- 3 Bedroom Apt  1.539489e+08
# 7                         City lights, Mountain heights  4.973294e+08
# 9                      Dollar View, 9 km to city center  2.984566e+08
# 15                        A fabulous place on riccarton  6.690307e+08
# ...                                                 ...           ...
# 28744    Stylish CBD Studio | Top Location Close To All  7.061957e+08
# 28761                 Comfortable Three-Bedroom Home U6  7.481114e+07
# 28765                                 Innes Rd Parkside  2.420551e+07
# 28768            Refurbished villa in a great location!  1.696062e+08
# 28792  Unique central city standalone home with parking  1.673594e+18
#
#                                 host_name neighbourhood_group   neighbourhood  \
# 0                North South Holiday Park   Christchurch City   Harewood Ward
# 5                              Alisa Kate   Christchurch City  Fendalton Ward
# 7                                 Michael   Christchurch City  Heathcote Ward
# 9                                    Tony   Christchurch City  Heathcote Ward
# 15                               Anh Khoa   Christchurch City  Riccarton Ward
# ...                                   ...                 ...             ...
# 28744                                 Min   Christchurch City    Central Ward
# 28761                              Maggie   Christchurch City  Riccarton Ward
# 28765  Mayie, Judi And Karen At Bookahome   Christchurch City    Papanui Ward
# 28768                               Giana   Christchurch City      Innes Ward
# 28792                                Mike   Christchurch City    Central Ward
#
#         latitude   longitude        room_type  price  minimum_nights  \
# 0     -43.470020  172.570880     Private room    NaN             1.0
# 5     -43.511080  172.623880  Entire home/apt  585.0             2.0
# 7     -43.562280  172.712870  Entire home/apt  450.0             2.0
# 9     -43.564680  172.710980     Private room    NaN             1.0
# 15    -43.528600  172.569310  Entire home/apt  190.0             1.0
# ...          ...         ...              ...    ...             ...
# 28744 -43.529576  172.644619  Entire home/apt    NaN             1.0
# 28761 -43.534630  172.603750  Entire home/apt    NaN             1.0
# 28765 -43.502910  172.631883  Entire home/apt    NaN             2.0
# 28768 -43.511425  172.649259  Entire home/apt  742.0             1.0
# 28792 -43.524128  172.642483  Entire home/apt  169.0             3.0
#
#        number_of_reviews last_review reviews_per_month  \
# 0                      0         NaT               NaT
# 5                      0         NaT               NaT
# 7                      0         NaT               NaT
# 9                      0         NaT               NaT
# 15                     0         NaT               NaT
# ...                  ...         ...               ...
# 28744                  0         NaT               NaT
# 28761                  0         NaT               NaT
# 28765                  0         NaT               NaT
# 28768                  0         NaT               NaT
# 28792                  0         NaT               NaT
#
#        calculated_host_listings_count  availability_365  \
# 0                                20.0               317
# 5                                 3.0                78
# 7                                 1.0               363
# 9                                 6.0                 0
# 15                                1.0               282
# ...                               ...               ...
# 28744                             1.0                 0
# 28761                            43.0                 0
# 28765                            80.0                 0
# 28768                             1.0               353
# 28792                             2.0               102
#
#        number_of_reviews_ltm   Pub_date  Difference_date
# 0                          0 2025-11-07              NaN
# 5                          0 2025-11-07              NaN
# 7                          0 2025-11-07              NaN
# 9                          0 2025-11-07              NaN
# 15                         0 2025-11-07              NaN
# ...                      ...        ...              ...
# 28744                      0 2026-06-19              NaN
# 28761                      0 2026-06-19              NaN
# 28765                      0 2026-06-19              NaN
# 28768                      0 2026-06-19              NaN
# 28792                      0 2026-06-19              NaN
#
# [2586 rows x 18 columns]

# %%
df_all_christ['host_id'] = df_all_christ['host_id'].astype('Int64').astype(str)

# %%
df_all_christ.sample(5)
# Out:
#                                                     name    host_id  \
# 28524          Modern CBD Townhouse close to new stadium  742505821
# 2405                  Central 3BR w/Fire Pit and Parking  439038269
# 25733   Peaceful Akaroa retreat for couples & solo stays  120625017
# 17219     Inner City Executive Apartment with EV Parking   24205506
# 24545  HOME AWAY FROM HOME\nARENA#STADIUM#TRANZALPINE...  125315385
#
#                                 host_name neighbourhood_group  \
# 28524                               Laura   Christchurch City
# 2405                               Serena   Christchurch City
# 25733                           Tim & Sal   Christchurch City
# 17219  Mayie, Judi And Karen At Bookahome   Christchurch City
# 24545                   Leeanne And David   Christchurch City
#
#               neighbourhood   latitude   longitude        room_type  price  \
# 28524          Central Ward -43.529574  172.643785  Entire home/apt  178.0
# 2405           Central Ward -43.528281  172.644990  Entire home/apt  245.0
# 25733  Banks Peninsula Ward -43.808999  172.982954  Entire home/apt  235.0
# 17219          Central Ward -43.532750  172.641000  Entire home/apt  250.0
# 24545         Spreydon Ward -43.549620  172.603550  Entire home/apt  128.0
#
#        minimum_nights  number_of_reviews last_review  \
# 28524             1.0                  5  2026-05-31
# 2405              1.0                 23  2025-09-28
# 25733             2.0                 18  2026-06-13
# 17219             2.0                 59  2026-03-07
# 24545             1.0                691  2026-05-21
#
#                   reviews_per_month  calculated_host_listings_count  \
# 28524 1970-01-01 00:00:00.000000002                             1.0
# 2405  1970-01-01 00:00:00.000000005                             1.0
# 25733 1970-01-01 00:00:00.000000003                             1.0
# 17219 1970-01-01 00:00:00.000000002                            83.0
# 24545 1970-01-01 00:00:00.000000006                             1.0
#
#        availability_365  number_of_reviews_ltm   Pub_date  Difference_date
# 12504               222                      1 2026-02-13             82.0
# 11759               130                     36 2026-01-16              7.0

# %%
df_all_christ[df_all_christ['last_review'].isna()]
# Out:
#                                                    name              host_id  \
# 0                              Ensuite Cabin (Sleeps 6)             98758734
# 5               Merivale Executive Stays- 3 Bedroom Apt            153948924
# 7                         City lights, Mountain heights            497329414
# 9                      Dollar View, 9 km to city center            298456605
# 15                        A fabulous place on riccarton            669030702
# ...                                                 ...                  ...
# 28744    Stylish CBD Studio | Top Location Close To All            706195697
# 28761                 Comfortable Three-Bedroom Home U6             74811135
# 28765                                 Innes Rd Parkside             24205506
# 28768            Refurbished villa in a great location!            169606230
# 28792  Unique central city standalone home with parking  1673594072955121408
#
#                                 host_name neighbourhood_group   neighbourhood  \
# 0                North South Holiday Park   Christchurch City   Harewood Ward
# 5                              Alisa Kate   Christchurch City  Fendalton Ward
# 7                                 Michael   Christchurch City  Heathcote Ward
# 9                                    Tony   Christchurch City  Heathcote Ward
# 15                               Anh Khoa   Christchurch City  Riccarton Ward
# ...                                   ...                 ...             ...
# 28744                                 Min   Christchurch City    Central Ward
# 28761                              Maggie   Christchurch City  Riccarton Ward
# 28765  Mayie, Judi And Karen At Bookahome   Christchurch City    Papanui Ward
# 28768                               Giana   Christchurch City      Innes Ward
# 28792                                Mike   Christchurch City    Central Ward
#
#         latitude   longitude        room_type  price  minimum_nights  \
# 0     -43.470020  172.570880     Private room    NaN             1.0
# 5     -43.511080  172.623880  Entire home/apt  585.0             2.0
# 7     -43.562280  172.712870  Entire home/apt  450.0             2.0
# 9     -43.564680  172.710980     Private room    NaN             1.0
# 15    -43.528600  172.569310  Entire home/apt  190.0             1.0
# ...          ...         ...              ...    ...             ...
# 28744 -43.529576  172.644619  Entire home/apt    NaN             1.0
# 28761 -43.534630  172.603750  Entire home/apt    NaN             1.0
# 28765 -43.502910  172.631883  Entire home/apt    NaN             2.0
# 28768 -43.511425  172.649259  Entire home/apt  742.0             1.0
# 28792 -43.524128  172.642483  Entire home/apt  169.0             3.0
#
#        number_of_reviews last_review reviews_per_month  \
# 0                      0         NaT               NaT
# 5                      0         NaT               NaT
# 7                      0         NaT               NaT
# 9                      0         NaT               NaT
# 15                     0         NaT               NaT
# ...                  ...         ...               ...
# 28744                  0         NaT               NaT
# 28761                  0         NaT               NaT
# 28765                  0         NaT               NaT
# 28768                  0         NaT               NaT
# 28792                  0         NaT               NaT
#
#        calculated_host_listings_count  availability_365  \
# 0                                20.0               317
# 5                                 3.0                78
# 7                                 1.0               363
# 9                                 6.0                 0
# 15                                1.0               282
# ...                               ...               ...
# 28744                             1.0                 0
# 28761                            43.0                 0
# 28765                            80.0                 0
# 28768                             1.0               353
# 28792                             2.0               102
#
#        number_of_reviews_ltm   Pub_date  Difference_date
# 0                          0 2025-11-07              NaN
# 5                          0 2025-11-07              NaN
# 7                          0 2025-11-07              NaN
# 9                          0 2025-11-07              NaN
# 15                         0 2025-11-07              NaN
# ...                      ...        ...              ...
# 28744                      0 2026-06-19              NaN
# 28761                      0 2026-06-19              NaN
# 28765                      0 2026-06-19              NaN
# 28768                      0 2026-06-19              NaN
# 28792                      0 2026-06-19              NaN
#
# [2586 rows x 18 columns]

# %%
df_all_christ.isna().sum()
# Out:
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             10627
# minimum_nights                       37
# number_of_reviews                     0
# last_review                        2586
# reviews_per_month                  2586
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# Pub_date                              0
# Difference_date                    2586
# dtype: int64

# %%
df_all_christ[df_all_christ['price'] == "NA"].head()
# Out:
# Empty DataFrame
# Columns: [name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, Pub_date, Difference_date]
# Index: []

# %%
df_all_christ[df_all_christ['price'].isna()].head()
# Out:
#                                name    host_id                 host_name  \
# 0          Ensuite Cabin (Sleeps 6)   98758734  North South Holiday Park
# 1    Handy city center. Simple room  298456605                      Tony
# 3           Settle into the sun set   54299306                    Sarena
# 8                 Wigram sunny room  302657091                   Hongmei
# 9  Dollar View, 9 km to city center  298456605                      Tony
#
#   neighbourhood_group   neighbourhood   latitude  longitude        room_type  \
# 0   Christchurch City   Harewood Ward -43.470020  172.57088     Private room
# 1   Christchurch City    Central Ward -43.532700  172.66403     Private room
# 3   Christchurch City    Burwood Ward -43.482864  172.66866  Entire home/apt
# 8   Christchurch City   Halswell Ward -43.558840  172.55375     Private room
# 9   Christchurch City  Heathcote Ward -43.564680  172.71098     Private room
#
#    price  minimum_nights  number_of_reviews last_review  \
# 0    NaN             1.0                  0         NaT
# 1    NaN             1.0                 25  2025-07-15
# 3    NaN             2.0                  2  2025-04-26
# 8    NaN             1.0                  1  2019-12-31
# 9    NaN             1.0                  0         NaT
#
#               reviews_per_month  calculated_host_listings_count  \
# 0                           NaT                            20.0
# 1 1970-01-01 00:00:00.000000001                             6.0
# 3 1970-01-01 00:00:00.000000000                             1.0
# 8 1970-01-01 00:00:00.000000000                             2.0
# 9                           NaT                             6.0
#
#    availability_365  number_of_reviews_ltm   Pub_date  Difference_date
# 0               317                      0 2025-11-07              NaN
# 1                 0                     21 2025-11-07            115.0
# 3                 0                      2 2025-11-07            195.0
# 8                 4                      0 2025-11-07           2138.0
# 9                 0                      0 2025-11-07              NaN

# %%
df_all_christ[
    df_all_christ['price'].isna() &
    df_all_christ['reviews_per_month'].isna() &
    df_all_christ['last_review'].isna()
].shape
# Out:
# (1077, 18)

# %%
df_all_christ[
    ['price', 'reviews_per_month', 'last_review']
].isna().value_counts()
# Out:
# price  reviews_per_month  last_review
# False  False              False          16547
# True   False              False           9550
# False  True               True            1509
# True   True               True            1077
# Name: count, dtype: int64

# %%
df_all_christ[
    df_all_christ['price'].isna()
]['neighbourhood'].value_counts().head(20)
# Out:
# neighbourhood
# Central Ward            3674
# Banks Peninsula Ward    1394
# Heathcote Ward           821
# Riccarton Ward           702
# Fendalton Ward           633
# Halswell Ward            392
# Cashmere Ward            390
# Innes Ward               386
# Spreydon Ward            382
# Coastal Ward             341
# Waimairi Ward            333
# Harewood Ward            330
# Papanui Ward             246
# Linwood Ward             233
# Hornby Ward              219
# Burwood Ward             151
# Name: count, dtype: int64

# %%
df_all_christ[
    df_all_christ['price'].isna()
]['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    8366
# Private room       2146
# Hotel room          103
# Shared room          12
# Name: count, dtype: int64

# %%
df_all_christ.groupby('room_type')['price'].apply(
    lambda x: x.isna().mean() * 100
)
# Out:
# room_type
# Entire home/apt    36.838397
# Hotel room         41.035857
# Private room       37.728551
# Shared room        35.294118
# Name: price, dtype: float64

# %%
df_all_christ.groupby('neighbourhood')['price'].apply(
    lambda x: x.isna().mean() * 100
).sort_values(ascending=False)
# Out:
# neighbourhood
# Burwood Ward            40.810811
# Heathcote Ward          39.912494
# Fendalton Ward          39.488459
# Banks Peninsula Ward    39.389658
# Cashmere Ward           38.805970
# Coastal Ward            38.531073
# Papanui Ward            38.021638
# Waimairi Ward           37.927107
# Innes Ward              37.769080
# Riccarton Ward          37.459979
# Hornby Ward             37.308348
# Halswell Ward           36.635514
# Harewood Ward           36.504425
# Spreydon Ward           36.311787
# Linwood Ward            35.518293
# Central Ward            34.877539
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))

plt.boxplot(
    df_all_christ['price'].dropna(),
    vert=False
)

plt.xlabel('Price')
plt.title('Box Plot of Airbnb Price')

plt.show()
# Out:
# C:\Users\VISHAL\AppData\Local\Temp\ipykernel_23168\3141972734.py:5: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(

# %%
Q1 = df_all_christ['price'].quantile(0.25)
Q3 = df_all_christ['price'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower bound:", lower_bound)
print("Upper bound:", upper_bound)
# Out:
# Q1: 140.0
# Q3: 284.0
# IQR: 144.0
# Lower bound: -76.0
# Upper bound: 500.0

# %%
outliers = df_all_christ[
    (df_all_christ['price'] < lower_bound) |
    (df_all_christ['price'] > upper_bound)
]

outliers[['name', 'room_type', 'neighbourhood', 'price']].head()
# Out:
#                                            name        room_type  \
# 5       Merivale Executive Stays- 3 Bedroom Apt  Entire home/apt
# 59             Big Sky Retreat, house and yurts  Entire home/apt
# 60        Seaview Outlook - Wainui Holiday Home  Entire home/apt
# 123  Executive Home with Stunning Harbour views  Entire home/apt
# 156                        Seaglass Beach House  Entire home/apt
#
#             neighbourhood    price
# 5          Fendalton Ward    585.0
# 59   Banks Peninsula Ward    900.0
# 60   Banks Peninsula Ward  43188.0
# 123  Banks Peninsula Ward    758.0
# 156          Coastal Ward    591.0

# %%
len(outliers)
# Out:
# 938

# %%
outliers['price'].describe()
# Out:
# count      938.000000
# mean      1175.401919
# std       4017.553200
# min        501.000000
# 25%        562.000000
# 50%        657.000000
# 75%        855.750000
# max      43654.000000
# Name: price, dtype: float64

# %%
outliers[['name', 'room_type', 'neighbourhood', 'price']].sort_values(
    'price',
    ascending=False
).head(20)
# Out:
#                                                     name        room_type  \
# 5873           Central Cutie - Christchurch City Cottage  Entire home/apt
# 3707      La Maison de Manu Waiata - Akaroa Holiday Home  Entire home/apt
# 3945               Seaview Outlook - Wainui Holiday Home  Entire home/apt
# 5719   Pacific Panorama - Christchurch Holiday Apartment  Entire home/apt
# 1786      La Maison de Manu Waiata - Akaroa Holiday Home  Entire home/apt
# 2088   Pacific Panorama - Christchurch Holiday Apartment  Entire home/apt
# 60                 Seaview Outlook - Wainui Holiday Home  Entire home/apt
# 1451           Central Cutie - Christchurch City Cottage  Entire home/apt
# 23208     Groups wanted CHCH CBD 3bed 3 bath with garage  Entire home/apt
# 18892                                 The East Penthouse     Private room
# 15663                                 The East Penthouse     Private room
# 28260                                 The East Penthouse     Private room
# 25168                                 The East Penthouse     Private room
# 928                                   The East Penthouse     Private room
# 5763     Elegant Mansion for Weddings, Business & Family  Entire home/apt
# 553      Elegant Mansion for Weddings, Business & Family  Entire home/apt
# 19717      Exquisite Contemporary Haven · Luxury Retreat  Entire home/apt
# 18078    Elegant Mansion for Weddings, Business & Family  Entire home/apt
# 5808                    Executive House - Huntsbury Hill  Entire home/apt
# 1706                    Executive House - Huntsbury Hill  Entire home/apt
#
#               neighbourhood    price
# 5873           Central Ward  43654.0
# 3707   Banks Peninsula Ward  43654.0
# 3945   Banks Peninsula Ward  43654.0
# 5719           Central Ward  43654.0
# 1786   Banks Peninsula Ward  43188.0
# 2088           Central Ward  43188.0
# 60     Banks Peninsula Ward  43188.0
# 1451           Central Ward  43178.0
# 23208          Central Ward  22971.0
# 18892          Central Ward   6277.0
# 15663          Central Ward   6277.0
# 28260          Central Ward   6277.0
# 25168          Central Ward   6277.0
# 928            Central Ward   5000.0
# 5763          Cashmere Ward   3029.0
# 553           Cashmere Ward   3029.0
# 19717        Heathcote Ward   2470.0
# 18078         Cashmere Ward   2350.0
# 5808          Cashmere Ward   2250.0
# 1706          Cashmere Ward   2250.0

# %% [markdown]
# ## not remove out liers may be some property have highr value, so we use meidean methode not mean

# %%
group_median = (
    df_all_christ
    .groupby(['room_type', 'neighbourhood'])['price']
    .transform('median')
)
group_median
# Out:
# 0        137.0
# 1        125.0
# 2         92.0
# 3        179.0
# 4        139.5
#          ...
# 28790    220.0
# 28791    220.0
# 28792    220.0
# 28793    220.0
# 28794    252.0
# Name: price, Length: 28683, dtype: float64

# %%
median_price = (
    df_all_christ
    .groupby(['room_type', 'neighbourhood'])['price']
    .median()
   
)

median_price
# Out:
# room_type        neighbourhood
# Entire home/apt  Banks Peninsula Ward    252.0
#                  Burwood Ward            179.0
#                  Cashmere Ward           177.0
#                  Central Ward            220.0
#                  Coastal Ward            178.0
#                  Fendalton Ward          241.0
#                  Halswell Ward           285.0
#                  Harewood Ward           189.0
#                  Heathcote Ward          252.0
#                  Hornby Ward             250.0
#                  Innes Ward              232.0
#                  Linwood Ward            202.5
#                  Papanui Ward            206.0
#                  Riccarton Ward          226.0
#                  Spreydon Ward           205.5
#                  Waimairi Ward           194.0
# Hotel room       Banks Peninsula Ward    272.0
#                  Central Ward            290.0
#                  Papanui Ward            200.5
# Private room     Banks Peninsula Ward    172.0
#                  Burwood Ward             70.0
#                  Cashmere Ward           101.0
#                  Central Ward            125.0
#                  Coastal Ward             92.0
#                  Fendalton Ward           92.0
#                  Halswell Ward            91.0
#                  Harewood Ward           137.0
#                  Heathcote Ward          102.0
#                  Hornby Ward              84.0
#                  Innes Ward               92.0
#                  Linwood Ward             72.0
#                  Papanui Ward             86.0
#                  Riccarton Ward          139.5
#                  Spreydon Ward            77.5
#                  Waimairi Ward            85.5
# Shared room      Central Ward             49.0
#                  Spreydon Ward            65.5
# Name: price, dtype: float64

# %%
df_all_christ.groupby("room_type")["price"].median()
# Out:
# room_type
# Entire home/apt    224.0
# Hotel room         245.0
# Private room       103.0
# Shared room         57.5
# Name: price, dtype: float64

# %%
price_before = df_all_christ['price'].copy()

# %%
df_all_christ['price'] = (
    df_all_christ
    .groupby(['room_type', 'neighbourhood'])['price']
    .transform(lambda x: x.fillna(x.median()))
)

# %%
 df_all_christ['price'].isna().sum()
# Out:
# np.int64(0)

# %%
print(price_before.describe())


print(df_all_christ['price'].describe())
# Out:
# count    18056.000000
# mean       260.073161
# std        944.794565
# min         27.000000
# 25%        140.000000
# 50%        205.000000
# 75%        284.000000
# max      43654.000000
# Name: price, dtype: float64
# count    28683.000000
# mean       238.832688
# std        750.796729
# min         27.000000
# 25%        151.000000
# 50%        220.000000
# 75%        252.000000
# max      43654.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8, 5))

plt.boxplot(
     [price_before.dropna(), df_all_christ['price'].dropna()],
     tick_labels=['Before', 'After']
)

plt.ylabel('Price')
plt.title('Price Distribution Before and After Imputation')
plt.show()

# %%
df_all_christ[['reviews_per_month', 'last_review','Difference_date']] = (
    df_all_christ[['reviews_per_month', 'last_review','Difference_date']].fillna(0)
)

# %%
df_all_christ.isna().sum()
# Out:
# name                               0
# host_id                            0
# host_name                          1
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                    37
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# number_of_reviews_ltm              0
# Pub_date                           0
# Difference_date                    0
# dtype: int64

# %%
df_all_christ[df_all_christ['minimum_nights'].isna()]
# Out:
#                                                     name    host_id  \
# 9274              Deluxe Private Studio close to Airport   90897150
# 9330                    Character, quiet, new (CNZhouse)   55183024
# 9540                                   Beachtown retreat  220662178
# 9710                     Lyttel West B & B with spa pool   99496641
# 9833   CBD Luxury Parkside Living 2 Bedroom With Parking  542767166
# 9894   Peaceful Garden Studio: separate, no cleaning fee  183232246
# 10298   Location, Style, Practicality - carpark included   45172785
# 10652                     The Salisbury - 2-Bedroom Home  202585247
# 10955  Christchurch 4bdrm close to Hagley Park Riccarton   76237120
# 11229                                     Coniston Cabin   97678070
# 11623                       A Hidden Gem on Lincoln Road  155024348
# 12179   Stylish City Apartment with  Balcony and Parking   45768555
# 12463           Quiet and peaceful luxury at a low price   32636421
# 13661          Chic, modern, 3 bdrm apartment - Merivale   47808157
# 13724                     Hagley Haven | Guest Favourite  238339893
# 13743              Prime Location Handy CBD& Restaurants   45768555
# 15128     The little Gem at Merivale close to everything  129377311
# 15133               Manor Apartment with Wifi and Sky TV   43226526
# 15192    LOCATION, LOCATION! SUNNY TOWNHOUSE IN MERIVALE  386394417
# 15367           Modern Central  City 4 Bedroom Townhouse  239600018
# 15373        Riverside Retreat on Terrace | Pet Friendly  172091254
# 15374  New! Charming 2BR w/ Free Parking on Glouceste...  202585247
# 15377  City Apartment by Riverside Market & the Hospital   55863813
# 15381                        Rose Cottage. Central City.   54292480
# 15383   Location, Style, Practicality - carpark included   45172785
# 12179                      3 2026-01-16              7.0
# 12463                      1 2026-02-13             27.0
# 13661                      0 2026-02-13           1112.0
# 13724                    140 2026-02-13             -2.0
# 13743                     12 2026-02-13             12.0
# 15128                    101 2026-02-13             -2.0
# 15133                      7 2026-02-13             -1.0
# 15192                     31 2026-02-13              0.0
# 15367                     11 2026-02-13              1.0
# 15373                     33 2026-02-13             -2.0
# 15374                     32 2026-02-13             12.0
# 15377                     65 2026-02-13             12.0
# 15381                     52 2026-02-13             12.0
# 15383                     36 2026-02-13             20.0
# 15384                      3 2026-02-13             12.0
# 15385                      6 2026-02-13             12.0
# 15386                     25 2026-02-13              6.0
# 16626                     44 2026-03-17              2.0
# 19252                     76 2026-04-16              6.0
# 19849                     45 2026-04-16             -3.0
# 20961                     28 2026-04-16              4.0
# 21999                     28 2026-05-23             -2.0
# 22687                      0 2026-05-23              0.0
# 23511                     45 2026-05-23              7.0
# 25930                     62 2026-06-19              5.0
# 26828                     79 2026-06-19              1.0

# %%
df_all_christ['minimum_nights'].describe()
# Out:
# count    28646.000000
# mean         1.781924
# std          5.502746
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        365.000000
# Name: minimum_nights, dtype: float64

# %%
df_all_christ['minimum_nights'] = (
    df_all_christ['minimum_nights']
    .fillna(df_all_christ['minimum_nights'].median())
)

# %%
df_all_christ.isna().sum()
# Out:
# name                              0
# host_id                           0
# host_name                         1
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# Pub_date                          0
# Difference_date                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.hist(
    price_before.dropna(),
    bins=50,
    alpha=0.5,
    label='Before imputation',
    range=(0, 1000)
)

plt.hist(
    df_all_christ['price'],
    bins=50,
    alpha=0.5,
    label='After imputation',
    range=(0, 1000)
)

plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution Before and After Imputation')
plt.legend()

plt.show()

# %%
all_christ['last_review']=pd.to_datetime(all_christ['last_review'])
all_christ['Pub_date']=pd.to_datetime(all_christ['Pub_date'])
all_christ['reviews_per_month']=pd.to_datetime(all_christ['reviews_per_month'])

# %%
all_christ.dtypes
# Out:
# id                                         int64
# name                                         str
# host_id                                  float64
# host_name                                    str
# neighbourhood_group                          str
# neighbourhood                                str
# latitude                                 float64
# longitude                                float64
# room_type                                    str
# price                                    float64
# minimum_nights                           float64
# number_of_reviews                          int64
# last_review                       datetime64[us]
# reviews_per_month                 datetime64[ns]
# calculated_host_listings_count           float64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                  float64
# Pub_date                          datetime64[us]
# Difference_date                          float64
# dtype: object

# %%
all_christ.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             10667
# minimum_nights                       37
# number_of_reviews                     0
# last_review                        2627
# reviews_per_month                  2627
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           28795
# Pub_date                              0
# Difference_date                    2627
# dtype: int64

# %%
all_christ['month'] = all_christ['last_review'].dt.month

# %%
all_christ['month_name'] = all_christ['last_review'].dt.month_name()

# %%
price_na = all_christ[all_christ['price'].isna()].copy()

# %%
price_na['month'] = price_na['last_review'].dt.month
price_na['month'] = price_na['last_review'].dt.month_name()
price_na.groupby('month').size()
# Out:
# month
# April         351
# August        147
# December     1602
# February     1685
# January      2943
# July          223
# June          141
# March         305
# May           135
# November     1387
# October       413
# September     249
# dtype: int64
