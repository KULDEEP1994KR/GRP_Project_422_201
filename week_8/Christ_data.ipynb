# %%
import pandas as pd

# %%
all_christ= pd.read_csv(r"C:\Users\VISHAL\Desktop\g2\All_chrch_file.csv")

# %%
all_christ.sample(10)
# Out:
#                         id                                               name  \
# 23559  1350266274214073236                                  Riverside Retreat
# 18896             18659644  Banks Peninsula Cottage-Paradise near Christch...
# 18219  1544618050761652842  * Walk to TownHall, Casino, Te Pae, Free Car park
# 26008   618234455671580077  Two Bedrooms townhouse with free Park near Hagley
# 16118             45915103    Te Whare Rimu -  a mix of character and comfort
# 26784  1050226937718084984        Views + Quiet, Akaroa Retreat- pet friendly
# 17356  1245257931483690310            Charming & Central Retreat with parking
# 21252  1494493797254620464     Luxury New Chic 2Bed Home Near Northlands Mall
# 16861  1020394580431484290                    Relax by the beach entire house
# 13824  1604770657887160295            Stylish Studio in the heart of the city
#
#            host_id                           host_name neighbourhood_group  \
# ...

# %%
df_all_christ= all_christ.drop(columns=["license","id",])

# %%
df_all_christ.sample(10)
# Out:
#                                                     name      host_id  \
# 21278                 City Haven 3 bed 3.5 bath + garage  108898953.0
# 22481                               Aylmers Valley Vista  553244065.0
# 214                                        Port Goodness  195093909.0
# 7300   Million dollar views in beautiful Diamond Harbour  431781991.0
# 6215                     Woodbury Cottage - Cozy & Quiet  329368423.0
# 8405                  Luxury Sunny Warm CBD At Doorstep.   45768555.0
# 26207  Luxurious 3-Bedroom Designer Townhouse With Ga...  551181197.0
# 13923                  Luxury CBD Apartment Free parking  510730797.0
# 14738                                   A room in a home  439826551.0
# 3800   Rapaki  Rendezvous by the Sea on Lyttelton Har...  324058622.0
#
#                  host_name neighbourhood_group         neighbourhood  \
# 21278              Annabel   Christchurch City          Central Ward
# ...

# %%
df_all_christ.dtypes
# Out:
# name                                  str
# host_id                           float64
# host_name                             str
# neighbourhood_group                   str
# neighbourhood                         str
# latitude                          float64
# longitude                         float64
# room_type                             str
# price                             float64
# minimum_nights                    float64
# number_of_reviews                   int64
# last_review                           str
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                    int64
# number_of_reviews_ltm               int64
# Pub_date                              str
# Difference_date                   float64
# dtype: object

# %%
df_all_christ['last_review']=pd.to_datetime(df_all_christ['last_review'])
df_all_christ['Pub_date']=pd.to_datetime(df_all_christ['Pub_date'])
df_all_christ['reviews_per_month']=pd.to_datetime(df_all_christ['reviews_per_month'])

# %%
df_all_christ.dtypes
# Out:
# name                                         str
# host_id                                  float64
# host_name                                    str
# neighbourhood_group                          str
# neighbourhood                                str
# latitude                                 float64
# longitude                                float64
# room_type                                    str
# price                                    float64
# minimum_nights                           float64
# number_of_reviews                          int64
# last_review                       datetime64[us]
# reviews_per_month                 datetime64[ns]
# calculated_host_listings_count           float64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# Pub_date                          datetime64[us]
# Difference_date                          float64
# dtype: object

# %%
df_all_christ["price"].isnull().sum()
# Out:
# np.int64(10667)

# %%
df_all_christ.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28795 entries, 0 to 28794
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            28795 non-null  str
#  1   host_id                         28795 non-null  float64
#  2   host_name                       28794 non-null  str
#  3   neighbourhood_group             28795 non-null  str
#  4   neighbourhood                   28795 non-null  str
#  5   latitude                        28795 non-null  float64
#  6   longitude                       28795 non-null  float64
#  7   room_type                       28795 non-null  str
#  8   price                           18128 non-null  float64
#  9   minimum_nights                  28758 non-null  float64
#  10  number_of_reviews               28795 non-null  int64
#  11  last_review                     26168 non-null  datetime64[us]
# ...

# %%
df_all_christ["last_review"].isnull().sum()
# Out:
# np.int64(2627)

# %%
print(df_all_christ.loc[df_all_christ['price'].isna(), 'price'])
# Out:
# 0       NaN
# 1       NaN
# 3       NaN
# 8       NaN
# 9       NaN
#          ..
# 28764   NaN
# 28765   NaN
# 28766   NaN
# 28767   NaN
# 28794   NaN
# Name: price, Length: 10667, dtype: float64

# %%
df_all_christ.duplicated().sum()
# Out:
# np.int64(112)

# %%
df_all_christ[df_all_christ.duplicated(keep=False)]
# Out:
#                                        name      host_id      host_name  \
# 3                   Settle into the sun set   54299306.0         Sarena
# 10    Room 3queen bedroom/separate bathroom   27743702.0          David
# 23         Max Penthouse 3 Bedroom with Spa  179297759.0           Peng
# 43                                   Cabino     962345.0          Rollo
# 45                          Beachside cabin  498286875.0           Anna
# ...                                     ...          ...            ...
# 5921                        Woolston wonder   91437295.0         Prisca
# 5937                       Birdsong retreat  216305400.0  Christine Joy
# 5942      Room with a View to the Mountains   32636421.0          Karyn
# 5944                       Room with a View   32636421.0          Karyn
# 5994         Entire 2-bed House in Woolston  159021723.0           Mark
#
#      neighbourhood_group         neighbourhood   latitude   longitude  \
# ...

# %%
df_all_christ[['name', 'host_id', 'host_name']].nunique()
# Out:
# name         4854
# host_id      2103
# host_name    1422
# dtype: int64

# %%
df_all_christ.groupby(
    ['name', 'host_id', 'host_name']
).size().sort_values(ascending=False).head(20)
# Out:
# name                                                host_id      host_name
# Waterfront 2-Bedroom Harbour View Apartment         20665858.0   Adam                                  20
# cozycozy guest house                                22181030.0   Flora                                 18
# Deluxe King Room                                    449624343.0  Lucy                                  17
# Quite and Cozy Double Bedroom                       662706872.0  Pratik                                16
# Room in Christchurch                                131216378.0  Adam                                  13
# Spacious stylish home - 7 Night special deals       24205506.0   Mayie, Judi And Karen At Bookahome    12
# Modern King Studio | Netflix, Disney+ & Parking     573757538.0  Prince                                12
# Brand-New 1BR Apartment Near Upcoming Te Kaha       331763232.0  Managed By Williams                   12
# ...

# %%
exact_duplicates = df_all_christ[
    df_all_christ.duplicated(keep=False)
]

exact_duplicates
# Out:
#                                        name      host_id      host_name  \
# 3                   Settle into the sun set   54299306.0         Sarena
# 10    Room 3queen bedroom/separate bathroom   27743702.0          David
# 23         Max Penthouse 3 Bedroom with Spa  179297759.0           Peng
# 43                                   Cabino     962345.0          Rollo
# 45                          Beachside cabin  498286875.0           Anna
# ...                                     ...          ...            ...
# 5921                        Woolston wonder   91437295.0         Prisca
# 5937                       Birdsong retreat  216305400.0  Christine Joy
# 5942      Room with a View to the Mountains   32636421.0          Karyn
# 5944                       Room with a View   32636421.0          Karyn
# 5994         Entire 2-bed House in Woolston  159021723.0           Mark
#
#      neighbourhood_group         neighbourhood   latitude   longitude  \
# ...

# %%
duplicates = df_all_christ[
    df_all_christ.duplicated(keep=False)
].sort_values(by=df_all_christ.columns.tolist())

duplicates
# Out:
#                                                 name      host_id  \
# 75                                     #Just4Goleman  443017458.0
# 3196                                   #Just4Goleman  443017458.0
# 1264  2 bed house near Beach + Cycleway 15min to CBD   64000316.0
# 3586  2 bed house near Beach + Cycleway 15min to CBD   64000316.0
# 314                     2 bedroom apartment- G02/36B   89191145.0
# ...                                              ...          ...
# 5921                                 Woolston wonder   91437295.0
# 1432         Your Home away from Home - Entire Home.  367682100.0
# 4496         Your Home away from Home - Entire Home.  367682100.0
# 2795                  Your separate space in Wigram.   55360169.0
# 4707                  Your separate space in Wigram.   55360169.0
#
#                    host_name neighbourhood_group   neighbourhood   latitude  \
# 75                       Jay   Christchurch City      Innes Ward -43.498730
# ...

# %%
df_all_christ = df_all_christ.drop_duplicates()

# %%
df_all_christ.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_all_christ.isna().sum()
# Out:
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             10627
# minimum_nights                       37
# number_of_reviews                     0
# last_review                        2586
# reviews_per_month                  2586
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# Pub_date                              0
# Difference_date                    2586
# dtype: int64

# %%
df_all_christ[df_all_christ['last_review'].isna()]
# Out:
#                                                    name       host_id  \
# 0                              Ensuite Cabin (Sleeps 6)  9.875873e+07
# 5               Merivale Executive Stays- 3 Bedroom Apt  1.539489e+08
# 7                         City lights, Mountain heights  4.973294e+08
# 9                      Dollar View, 9 km to city center  2.984566e+08
# 15                        A fabulous place on riccarton  6.690307e+08
# ...                                                 ...           ...
# 28744    Stylish CBD Studio | Top Location Close To All  7.061957e+08
# 28761                 Comfortable Three-Bedroom Home U6  7.481114e+07
# 28765                                 Innes Rd Parkside  2.420551e+07
# 28768            Refurbished villa in a great location!  1.696062e+08
# 28792  Unique central city standalone home with parking  1.673594e+18
#
#                                 host_name neighbourhood_group   neighbourhood  \
# ...

# %%
df_all_christ['host_id'] = df_all_christ['host_id'].astype('Int64').astype(str)

# %%
df_all_christ.sample(5)
# Out:
#                                                     name    host_id  \
# 1987                      Hilltop House with Ocean Views  131694130
# 21189  Sea-views in Redcliffs.\nStyle, comfort & bird...   80978447
# 15728                                    Spa Bath Studio   44728588
# 14318               Spacious Family Home in Top Location  133071277
# 12307                           Beautiful and clean Home  242127843
#
#          host_name neighbourhood_group   neighbourhood   latitude   longitude  \
# 1987        Hannah   Christchurch City  Heathcote Ward -43.563482  172.726499
# 21189          Amy   Christchurch City  Heathcote Ward -43.563651  172.734113
# 15728  Anita Marie   Christchurch City    Papanui Ward -43.485090  172.617740
# 14318       Nicole   Christchurch City  Fendalton Ward -43.519840  172.625340
# 12307     Jamerson   Christchurch City    Papanui Ward -43.470370  172.629310
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_all_christ.sample(20)
# Out:
#                                                     name    host_id  \
# 182                  Central 1bd I Carpark I Lift access   75857776
# 18512  City-Fringe Luxury Stay | 2BR Parking | Guest Fav   49642171
# 10045                      Modern Living in 1800's Hotel  140854309
# 2355    Cozy double bed bliss/ garden view/self check in  430177594
# 13169                                          Yondersea   36563950
# 28470                       Cathedral Junction Apartment  535222454
# 21970                                    Backpacker Twin   98758734
# 27499              3 Bed 2.5 Bath Riccarton W/Games room  482671075
# 13436                                Lavandula 4 Bedroom   24205506
# 28671                       Nestled in Nature, Near City   32539052
# 7803   Family Home, Ideal for Relocations, Pets Welcome!   53394004
# 20421                     Haka House - Entire 6 Bed Dorm  565751605
# 85     NEW,stylish, contemporary New Zealand architec...   95753227
# ...

# %%
df_all_christ[df_all_christ['last_review'].isna()]
# Out:
#                                                    name              host_id  \
# 0                              Ensuite Cabin (Sleeps 6)             98758734
# 5               Merivale Executive Stays- 3 Bedroom Apt            153948924
# 7                         City lights, Mountain heights            497329414
# 9                      Dollar View, 9 km to city center            298456605
# 15                        A fabulous place on riccarton            669030702
# ...                                                 ...                  ...
# 28744    Stylish CBD Studio | Top Location Close To All            706195697
# 28761                 Comfortable Three-Bedroom Home U6             74811135
# 28765                                 Innes Rd Parkside             24205506
# 28768            Refurbished villa in a great location!            169606230
# 28792  Unique central city standalone home with parking  1673594072955121408
#
# ...

# %%
df_all_christ.isna().sum()
# Out:
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             10627
# minimum_nights                       37
# number_of_reviews                     0
# last_review                        2586
# reviews_per_month                  2586
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# Pub_date                              0
# Difference_date                    2586
# dtype: int64

# %%
df_all_christ[df_all_christ['price'] == "NA"].head()
# Out:
# Empty DataFrame
# Columns: [name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, Pub_date, Difference_date]
# Index: []

# %%
df_all_christ[df_all_christ['price'].isna()].head()
# Out:
#                                name    host_id                 host_name  \
# 0          Ensuite Cabin (Sleeps 6)   98758734  North South Holiday Park
# 1    Handy city center. Simple room  298456605                      Tony
# 3           Settle into the sun set   54299306                    Sarena
# 8                 Wigram sunny room  302657091                   Hongmei
# 9  Dollar View, 9 km to city center  298456605                      Tony
#
#   neighbourhood_group   neighbourhood   latitude  longitude        room_type  \
# 0   Christchurch City   Harewood Ward -43.470020  172.57088     Private room
# 1   Christchurch City    Central Ward -43.532700  172.66403     Private room
# 3   Christchurch City    Burwood Ward -43.482864  172.66866  Entire home/apt
# 8   Christchurch City   Halswell Ward -43.558840  172.55375     Private room
# 9   Christchurch City  Heathcote Ward -43.564680  172.71098     Private room
#
#    price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_all_christ[
    df_all_christ['price'].isna() &
    df_all_christ['reviews_per_month'].isna() &
    df_all_christ['last_review'].isna()
].shape
# Out:
# (1077, 18)

# %%
df_all_christ[
    ['price', 'reviews_per_month', 'last_review']
].isna().value_counts()
# Out:
# price  reviews_per_month  last_review
# False  False              False          16547
# True   False              False           9550
# False  True               True            1509
# True   True               True            1077
# Name: count, dtype: int64

# %%
df_all_christ[
    df_all_christ['price'].isna()
]['neighbourhood'].value_counts().head(20)
# Out:
# neighbourhood
# Central Ward            3674
# Banks Peninsula Ward    1394
# Heathcote Ward           821
# Riccarton Ward           702
# Fendalton Ward           633
# Halswell Ward            392
# Cashmere Ward            390
# Innes Ward               386
# Spreydon Ward            382
# Coastal Ward             341
# Waimairi Ward            333
# Harewood Ward            330
# Papanui Ward             246
# Linwood Ward             233
# Hornby Ward              219
# Burwood Ward             151
# Name: count, dtype: int64

# %%
df_all_christ[
    df_all_christ['price'].isna()
]['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    8366
# Private room       2146
# Hotel room          103
# Shared room          12
# Name: count, dtype: int64

# %%
df_all_christ.groupby('room_type')['price'].apply(
    lambda x: x.isna().mean() * 100
)
# Out:
# room_type
# Entire home/apt    36.838397
# Hotel room         41.035857
# Private room       37.728551
# Shared room        35.294118
# Name: price, dtype: float64

# %%
df_all_christ.groupby('neighbourhood')['price'].apply(
    lambda x: x.isna().mean() * 100
).sort_values(ascending=False)
# Out:
# neighbourhood
# Burwood Ward            40.810811
# Heathcote Ward          39.912494
# Fendalton Ward          39.488459
# Banks Peninsula Ward    39.389658
# Cashmere Ward           38.805970
# Coastal Ward            38.531073
# Papanui Ward            38.021638
# Waimairi Ward           37.927107
# Innes Ward              37.769080
# Riccarton Ward          37.459979
# Hornby Ward             37.308348
# Halswell Ward           36.635514
# Harewood Ward           36.504425
# Spreydon Ward           36.311787
# Linwood Ward            35.518293
# Central Ward            34.877539
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))

plt.boxplot(
    df_all_christ['price'].dropna(),
    vert=False
)

plt.xlabel('Price')
plt.title('Box Plot of Airbnb Price')

plt.show()
# Out:
# C:\Users\VISHAL\AppData\Local\Temp\ipykernel_16188\3141972734.py:5: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(

# %%
Q1 = df_all_christ['price'].quantile(0.25)
Q3 = df_all_christ['price'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower bound:", lower_bound)
print("Upper bound:", upper_bound)
# Out:
# Q1: 140.0
# Q3: 284.0
# IQR: 144.0
# Lower bound: -76.0
# Upper bound: 500.0

# %%
outliers = df_all_christ[
    (df_all_christ['price'] < lower_bound) |
    (df_all_christ['price'] > upper_bound)
]

outliers[['name', 'room_type', 'neighbourhood', 'price']].head()
# Out:
#                                            name        room_type  \
# 5       Merivale Executive Stays- 3 Bedroom Apt  Entire home/apt
# 59             Big Sky Retreat, house and yurts  Entire home/apt
# 60        Seaview Outlook - Wainui Holiday Home  Entire home/apt
# 123  Executive Home with Stunning Harbour views  Entire home/apt
# 156                        Seaglass Beach House  Entire home/apt
#
#             neighbourhood    price
# 5          Fendalton Ward    585.0
# 59   Banks Peninsula Ward    900.0
# 60   Banks Peninsula Ward  43188.0
# 123  Banks Peninsula Ward    758.0
# 156          Coastal Ward    591.0

# %%
len(outliers)
# Out:
# 938

# %%
outliers['price'].describe()
# Out:
# count      938.000000
# mean      1175.401919
# std       4017.553200
# min        501.000000
# 25%        562.000000
# 50%        657.000000
# 75%        855.750000
# max      43654.000000
# Name: price, dtype: float64

# %%
outliers[['name', 'room_type', 'neighbourhood', 'price']].sort_values(
    'price',
    ascending=False
).head(20)
# Out:
#                                                     name        room_type  \
# 5873           Central Cutie - Christchurch City Cottage  Entire home/apt
# 3707      La Maison de Manu Waiata - Akaroa Holiday Home  Entire home/apt
# 3945               Seaview Outlook - Wainui Holiday Home  Entire home/apt
# 5719   Pacific Panorama - Christchurch Holiday Apartment  Entire home/apt
# 1786      La Maison de Manu Waiata - Akaroa Holiday Home  Entire home/apt
# 2088   Pacific Panorama - Christchurch Holiday Apartment  Entire home/apt
# 60                 Seaview Outlook - Wainui Holiday Home  Entire home/apt
# 1451           Central Cutie - Christchurch City Cottage  Entire home/apt
# 23208     Groups wanted CHCH CBD 3bed 3 bath with garage  Entire home/apt
# 18892                                 The East Penthouse     Private room
# 15663                                 The East Penthouse     Private room
# 28260                                 The East Penthouse     Private room
# ...

# %% [markdown]
# ## not remove out liers may be some property have highr value, so we use meidean methode not mean

# %%
group_median = (
    df_all_christ
    .groupby(['room_type', 'neighbourhood'])['price']
    .transform('median')
)
group_median
# Out:
# 0        137.0
# 1        125.0
# 2         92.0
# 3        179.0
# 4        139.5
#          ...
# 28790    220.0
# 28791    220.0
# 28792    220.0
# 28793    220.0
# 28794    252.0
# Name: price, Length: 28683, dtype: float64

# %%
median_price = (
    df_all_christ
    .groupby(['room_type', 'neighbourhood'])['price']
    .median()
   
)

median_price
# Out:
# room_type        neighbourhood
# Entire home/apt  Banks Peninsula Ward    252.0
#                  Burwood Ward            179.0
#                  Cashmere Ward           177.0
#                  Central Ward            220.0
#                  Coastal Ward            178.0
#                  Fendalton Ward          241.0
#                  Halswell Ward           285.0
#                  Harewood Ward           189.0
#                  Heathcote Ward          252.0
#                  Hornby Ward             250.0
#                  Innes Ward              232.0
#                  Linwood Ward            202.5
#                  Papanui Ward            206.0
#                  Riccarton Ward          226.0
#                  Spreydon Ward           205.5
#                  Waimairi Ward           194.0
# Hotel room       Banks Peninsula Ward    272.0
#                  Central Ward            290.0
#                  Papanui Ward            200.5
# ...

# %%
df_all_christ.groupby("room_type")["price"].median()
# Out:
# room_type
# Entire home/apt    224.0
# Hotel room         245.0
# Private room       103.0
# Shared room         57.5
# Name: price, dtype: float64

# %%
price_before = df_all_christ['price'].copy()

# %%
df_all_christ['price'] = (
    df_all_christ
    .groupby(['room_type', 'neighbourhood'])['price']
    .transform(lambda x: x.fillna(x.median()))
)

# %%
 df_all_christ['price'].isna().sum()
# Out:
# np.int64(0)

# %%
print(price_before.describe())


print(df_all_christ['price'].describe())
# Out:
# count    18056.000000
# mean       260.073161
# std        944.794565
# min         27.000000
# 25%        140.000000
# 50%        205.000000
# 75%        284.000000
# max      43654.000000
# Name: price, dtype: float64
# count    28683.000000
# mean       238.832688
# std        750.796729
# min         27.000000
# 25%        151.000000
# 50%        220.000000
# 75%        252.000000
# max      43654.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8, 5))

plt.boxplot(
     [price_before.dropna(), df_all_christ['price'].dropna()],
     tick_labels=['Before', 'After']
)

plt.ylabel('Price')
plt.title('Price Distribution Before and After Imputation')
plt.show()

# %%
df_all_christ[['reviews_per_month', 'last_review','Difference_date']] = (
    df_all_christ[['reviews_per_month', 'last_review','Difference_date']].fillna(0)
)

# %%
df_all_christ.isna().sum()
# Out:
# name                               0
# host_id                            0
# host_name                          1
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                    37
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# number_of_reviews_ltm              0
# Pub_date                           0
# Difference_date                    0
# dtype: int64

# %%
df_all_christ['minimum_nights'].describe()
# Out:
# count    28646.000000
# mean         1.781924
# std          5.502746
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        365.000000
# Name: minimum_nights, dtype: float64

# %%
df_all_christ['minimum_nights'] = (
    df_all_christ['minimum_nights']
    .fillna(df_all_christ['minimum_nights'].median())
)

# %%
df_all_christ.isna().sum()
# Out:
# name                              0
# host_id                           0
# host_name                         1
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# Pub_date                          0
# Difference_date                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.hist(
    price_before.dropna(),
    bins=50,
    alpha=0.5,
    label='Before imputation',
    range=(0, 1000)
)

plt.hist(
    df_all_christ['price'],
    bins=50,
    alpha=0.5,
    label='After imputation',
    range=(0, 1000)
)

plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution Before and After Imputation')
plt.legend()

plt.show()

# %%
all_christ['last_review']=pd.to_datetime(all_christ['last_review'])
all_christ['Pub_date']=pd.to_datetime(all_christ['Pub_date'])
all_christ['reviews_per_month']=pd.to_datetime(all_christ['reviews_per_month'])

# %%
all_christ.dtypes
# Out:
# id                                         int64
# name                                         str
# host_id                                  float64
# host_name                                    str
# neighbourhood_group                          str
# neighbourhood                                str
# latitude                                 float64
# longitude                                float64
# room_type                                    str
# price                                    float64
# minimum_nights                           float64
# number_of_reviews                          int64
# last_review                       datetime64[us]
# reviews_per_month                 datetime64[ns]
# calculated_host_listings_count           float64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                  float64
# Pub_date                          datetime64[us]
# ...

# %%
all_christ.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             10667
# minimum_nights                       37
# number_of_reviews                     0
# last_review                        2627
# reviews_per_month                  2627
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           28795
# Pub_date                              0
# Difference_date                    2627
# dtype: int64

# %%
all_christ['month'] = all_christ['Pub_date'].dt.month

# %%
all_christ['month_name'] = all_christ['Pub_date'].dt.month_name()

# %%
price_na = all_christ[all_christ['price'].isna()].copy()

# %%
price_na['month'] = price_na['Pub_date'].dt.month
price_na['month_name'] = price_na['Pub_date'].dt.month_name()
price_na.groupby('month_name').size()
# Out:
# month_name
# April        204
# December    3180
# February    3190
# January     3057
# June         274
# March        168
# May          212
# November     382
# dtype: int64

# %%
result = all_christ.groupby('month_name')['price'].agg(
    total='size',
    missing='size',
    non_missing='count'
)

result['missing'] = result['total'] - result['non_missing']

result
# Out:
#             total  missing  non_missing
# month_name
# April        3273      204         3069
# December     3180     3180            0
# February     3190     3190            0
# January      3057     3057            0
# June         3469      274         3195
# March        3227      168         3059
# May          3361      212         3149
# November     6038      382         5656

# %%
all_christ.sample(4)
# Out:
#                         id                                               name  \
# 6219   1189566749237087119  Cosy New Sleepout@ Papanui 40%Discount 4 longs...
# 11849             45081468                Modern Central City Sunny Apartment
# 17965  1462638886075643507       Luxurious and warm central Christchurch base
# 9794              22556692                                      Studio Access
#
#            host_id    host_name neighbourhood_group neighbourhood   latitude  \
# 6219   581194003.0       Esther   Christchurch City  Papanui Ward -43.471240
# 11849  363885946.0      Rebecca   Christchurch City  Central Ward -43.533360
# 17965    1003724.0        Vicky   Christchurch City  Central Ward -43.532066
# 9794    44728588.0  Anita Marie   Christchurch City  Papanui Ward -43.486750
#
#         longitude        room_type  price  ...  last_review  \
# 6219   172.617764  Entire home/apt    NaN  ...   2025-02-24
# 11849  172.641660  Entire home/apt    NaN  ...   2026-01-21
# ...

# %%
months_to_remove = ['December', 'February', 'January']

all_christ = all_christ[
    (
        all_christ['month_name'].isin(months_to_remove) &
        all_christ['price'].isna()
    )
].copy()

# %%
all_christ.shape
# Out:
# (19368, 22)

# %%
all_christ[
    all_christ['month_name'].isin(months_to_remove) &
    all_christ['price'].isna()
].shape
# Out:
# (0, 22)

# %%
result = all_christ.groupby('month_name')['price'].agg(
    total='size',
    missing='size',
    non_missing='count'
)

result['missing'] = result['total'] - result['non_missing']

result
# Out:
#             total  missing  non_missing
# month_name
# April        3273      204         3069
# June         3469      274         3195
# March        3227      168         3059
# May          3361      212         3149
# November     6038      382         5656

# %%
all_christ.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              1240
# minimum_nights                        9
# number_of_reviews                     0
# last_review                        1694
# reviews_per_month                  1694
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           19368
# Pub_date                              0
# Difference_date                    1694
# month                                 0
# month_name                            0
# dtype: int64

# %%
all_christ= all_christ.drop(columns=["license"])

# %%
all_christ.isna().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            1
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                             1240
# minimum_nights                       9
# number_of_reviews                    0
# last_review                       1694
# reviews_per_month                 1694
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# Pub_date                             0
# Difference_date                   1694
# month                                0
# month_name                           0
# dtype: int64
