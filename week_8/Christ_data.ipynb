# %%
import pandas as pd

# %%
all_christ= pd.read_csv(r"C:\Users\VISHAL\Desktop\g2\All_chrch_file.csv")

# %%
all_christ.sample(10)
# Out:
#                         id                                               name  \
# 9122   1435223539534463655                    Comfy room near hills and ocean
# 3353   1437316641058188086                       Beach House Taylor’s Mistake
# 22831             47475702            “Graylees” Stunning Private Family Home
# 4534   1345944538708947216  Convenient 1Bed Studio with Ensuite By Hagley ...
# 1400   1337204397842159080                       Cathedral Junction Apartment
# 15047   927059385903578638         Latimer Square 1 bed 1 bath - Single Level
# 21684  1601827855510006415      Victoria Jane Luxury Private Guest House Chch
# 15012  1390911116516704002    Bright City Base - 1Bed, Kitchen, Outdoor Space
# 1990   1504173086779310217   Private ground floor space with its own entrance
# 27413   993870335455542325                                      Parklands Pad
#
#            host_id            host_name neighbourhood_group   neighbourhood  \
# ...

# %%
df_all_christ= all_christ.drop(columns=["license","id",])

# %%
df_all_christ.sample(10)
# Out:
#                                                     name      host_id  \
# 18367     it's a home surrounding with lot of amenities.  732323895.0
# 10367                                 Inner City Comfort    2836786.0
# 6342                                  Moncks bay retreat    8558995.0
# 14949         City Terrace-3 Bedroom in CBD Free parking  584558161.0
# 9010                                   Deluxe Queen Room  270614463.0
# 16665           Cozy:Fully Equipped Unit 12noon check-in  153690508.0
# 21719  Classic Kiwi Bach - 2 Bed, 4 guests with Hot Tub.   20665858.0
# 7942                                    Chic in the City  176508106.0
# 25395                   Sea Side Paradise - Beach Across  514180659.0
# 16781  Beachside Townhouse,  2 Bedrooms 2-3 beds, 2 bath  537639282.0
#
#                host_name neighbourhood_group         neighbourhood   latitude  \
# 18367             Dhiren   Christchurch City         Cashmere Ward -43.564546
# ...

# %%
df_all_christ.dtypes
# Out:
# name                                  str
# host_id                           float64
# host_name                             str
# neighbourhood_group                   str
# neighbourhood                         str
# latitude                          float64
# longitude                         float64
# room_type                             str
# price                             float64
# minimum_nights                    float64
# number_of_reviews                   int64
# last_review                           str
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                    int64
# number_of_reviews_ltm               int64
# Pub_date                              str
# Difference_date                   float64
# dtype: object

# %%
df_all_christ['last_review']=pd.to_datetime(df_all_christ['last_review'])
df_all_christ['Pub_date']=pd.to_datetime(df_all_christ['Pub_date'])

# %%
df_all_christ.dtypes
# Out:
# name                                         str
# host_id                                  float64
# host_name                                    str
# neighbourhood_group                          str
# neighbourhood                                str
# latitude                                 float64
# longitude                                float64
# room_type                                    str
# price                                    float64
# minimum_nights                           float64
# number_of_reviews                          int64
# last_review                       datetime64[us]
# reviews_per_month                        float64
# calculated_host_listings_count           float64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# Pub_date                          datetime64[us]
# Difference_date                          float64
# dtype: object

# %%
df_all_christ["price"].isnull().sum()
# Out:
# np.int64(10667)

# %%
df_all_christ.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28795 entries, 0 to 28794
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            28795 non-null  str
#  1   host_id                         28795 non-null  float64
#  2   host_name                       28794 non-null  str
#  3   neighbourhood_group             28795 non-null  str
#  4   neighbourhood                   28795 non-null  str
#  5   latitude                        28795 non-null  float64
#  6   longitude                       28795 non-null  float64
#  7   room_type                       28795 non-null  str
#  8   price                           18128 non-null  float64
#  9   minimum_nights                  28758 non-null  float64
#  10  number_of_reviews               28795 non-null  int64
#  11  last_review                     26168 non-null  datetime64[us]
# ...

# %%
df_all_christ["last_review"].isnull().sum()
# Out:
# np.int64(2627)
