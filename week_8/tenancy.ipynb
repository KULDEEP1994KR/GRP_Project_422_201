# %%
import pandas as pd

# %%
df_tnc= pd.read_csv(r"C:\Users\VISHAL\Desktop\g2\Detailed-Quarterly-Tenancy-Q1-2020-Q3-2026.csv")

# %%
df_tnc.sample(10)
# Out:
#          TimeFrame  Location Id Dwelling Type Number Of Beds  Total Bonds  \
# 161716  2021-10-01     340400.0           ALL            ALL           18
# 165186  2021-10-01     362200.0         House            ALL           12
# 167437  2021-07-01     134500.0     Apartment              1           24
# 53659   2025-01-01     159000.0         House            ALL           18
# 195559  2020-10-01     309300.0           ALL            ALL            6
# 39199   2025-04-01     102800.0           ALL            ALL           12
# 172708  2021-07-01     200900.0         House            ALL            9
# 184352  2021-01-01     127300.0           ALL            ALL           36
# 112983  2023-04-01     174600.0         House              3            6
# 92791   2023-10-01     326100.0           ALL              3            6
#
#         Active Bonds  Closed Bonds  Median Rent  Geometric Mean Rent  \
# 161716           162            24        380.0                358.0
# ...

# %%
df_tnc.describe()
# Out:
#          Location Id    Total Bonds   Active Bonds   Closed Bonds  \
# count  225286.000000  226080.000000  226080.000000  226080.000000
# mean   209944.790466      33.807604     358.413973      27.973806
# std     79061.243519     600.844842    6755.815227     515.108357
# min       -99.000000       6.000000       0.000000       0.000000
# 25%    141500.000000       6.000000      48.000000       3.000000
# 50%    192800.000000       9.000000      93.000000       9.000000
# 75%    253100.000000      15.000000     165.000000      15.000000
# max    363300.000000   49875.000000  520821.000000   48384.000000
#
#          Median Rent  Geometric Mean Rent  Upper Quartile Rent  \
# count  225277.000000        225277.000000        225277.000000
# mean      574.009837           564.424433           635.220209
# std       167.703344           167.589406           194.942332
# min         0.000000             0.000000             0.000000
# ...

# %%
df_tnc.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 226080 entries, 0 to 226079
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   TimeFrame                226080 non-null  str
#  1   Location Id              225286 non-null  float64
#  2   Dwelling Type            226080 non-null  str
#  3   Number Of Beds           214071 non-null  str
#  4   Total Bonds              226080 non-null  int64
#  5   Active Bonds             226080 non-null  int64
#  6   Closed Bonds             226080 non-null  int64
#  7   Median Rent              225277 non-null  float64
#  8   Geometric Mean Rent      225277 non-null  float64
#  9   Upper Quartile Rent      225277 non-null  float64
#  10  Lower Quartile Rent      225277 non-null  float64
#  11  Log Std Dev Weekly Rent  225221 non-null  float64
# dtypes: float64(6), int64(3), str(3)
# memory usage: 20.7 MB

# %%
df_tnc.isna().sum()
# Out:
# TimeFrame                      0
# Location Id                  794
# Dwelling Type                  0
# Number Of Beds             12009
# Total Bonds                    0
# Active Bonds                   0
# Closed Bonds                   0
# Median Rent                  803
# Geometric Mean Rent          803
# Upper Quartile Rent          803
# Lower Quartile Rent          803
# Log Std Dev Weekly Rent      859
# dtype: int64

# %%
df_tnc['TimeFrame']=pd.to_datetime(df_tnc['TimeFrame'])
